# %% [markdown]
# <a href="https://colab.research.google.com/github/argONNY/Lab_1V2.0/blob/master/%D0%9A%D0%BE%D0%BF%D0%B8%D1%8F_%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%D0%B0_%22Untitled3_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt



x = np.linspace(0, 10, 100)
y = np.sin(x)
z = np.cos(x)

plt.figure(figsize=(7, 4))
plt.plot(x, y, label='sin(x)')
plt.plot(x, z, label='cos(x)')
plt.bar(x, y, edgecolor = 'red')
plt.plot(x, y, color='green')
plt.xlabel('x')
plt.ylabel('Значение')
plt.title('Графики sin(x) и cos(x)')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
data = np.random.normal(loc=0, scale=1, size=1000)

# Гистограмма
plt.figure(figsize=(8, 5))
plt.hist(data, bins=20, color='purple', edgecolor='black')
plt.title('Гистограмма нормального распределения')
plt.xlabel('Значения')
plt.ylabel('Частота')
plt.grid(True)
plt.show()

# %%
matrix = np.random.randint(1, 11, size=(5, 5))
mean_val = np.mean(matrix)
max_val = np.max(matrix)
min_val = np.min(matrix)
sum_by_columns = np.sum(matrix, axis= 0)
print("Матрица",matrix)
print("Максимум",max_val)
print("Минимум", min_val)
print("Среденее значение:", mean_val)
print("Сумма по столбцам", sum_by_columns)
# Out:
# Матрица [[ 8  7  1  8  6]
#  [ 9 10  6  9  8]
#  [ 4  1  8 10  6]
#  [ 1  2 10  6  1]
#  [10  9  1  2  2]]
# Максимум 10
# Минимум 1
# Среденее значение: 5.8
# Сумма по столбцам [32 29 26 35 23]

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.figure(figsize=(6,6))
plt.imshow(matrix, cmap="карта")
plt.colorbar(label="Значение")
for i in range(matrix.shape[0]):
  for o in range(matrix.shape[1]):
    plt.text(o, i,matrix[i, o], )
